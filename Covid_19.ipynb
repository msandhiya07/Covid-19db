# %% [markdown]
# <a href="https://colab.research.google.com/github/msandhiya07/Covid-19db/blob/main/Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/Covid-19.csv")

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.count()
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# #1 show the number of confirmed, deaths and recovery cases in each region

# %%
data.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.groupby("Country/Region")["Deaths"].sum()
# Out:
# Country/Region
# Afghanistan           1269
# Albania                144
# Algeria               1163
# Andorra                 52
# Angola                  41
#                       ...
# West Bank and Gaza      78
# Western Sahara           1
# Yemen                  483
# Zambia                 140
# Zimbabwe                36
# Name: Deaths, Length: 187, dtype: int64

# %%
data.groupby("Country/Region")["Confirmed"].sum()
# Out:
# Country/Region
# Afghanistan           36263
# Albania                4880
# Algeria               27973
# Andorra                 907
# Angola                  950
#                       ...
# West Bank and Gaza    10621
# Western Sahara           10
# Yemen                  1691
# Zambia                 4552
# Zimbabwe               2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby("Country/Region")["Recovered"].sum()
# Out:
# Country/Region
# Afghanistan           25198
# Albania                2745
# Algeria               18837
# Andorra                 803
# Angola                  242
#                       ...
# West Bank and Gaza     3752
# Western Sahara            8
# Yemen                   833
# Zambia                 2815
# Zimbabwe                542
# Name: Recovered, Length: 187, dtype: int64

# %%
data.groupby("Country/Region")["Confirmed"].sum().sort_values(ascending=True).head(10)
# Out:
# Country/Region
# Western Sahara           10
# Holy See                 12
# Greenland                14
# Saint Kitts and Nevis    17
# Dominica                 18
# Laos                     20
# Grenada                  23
# Timor-Leste              24
# Saint Lucia              24
# Fiji                     27
# Name: Confirmed, dtype: int64

# %%
data.groupby("Country/Region")["Confirmed"].sum().sort_values(ascending=False).head(10)
# Out:
# Country/Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Name: Confirmed, dtype: int64

# %%
data.groupby("Country/Region")["Confirmed"].sum()
